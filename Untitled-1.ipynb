# %%
import baostock as bs
import pandas as pd

lg = bs.login()
print('login respond error_code:'+lg.error_code)
print('login respond  error_msg:'+lg.error_msg)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success

# %%
rs = bs.query_sz50_stocks()

print('query_sz50 error_code:'+rs.error_code)

print('query_sz50  error_msg:'+rs.error_msg)
# Out:
# query_sz50 error_code:0
# query_sz50  error_msg:success

# %%
sz50_stocks = rs.get_data()
sz50_stocks
# Out:
#     updateDate       code code_name
# 0   2024-03-18  sh.600028      中国石化
# 1   2024-03-18  sh.600030      中信证券
# 2   2024-03-18  sh.600031      三一重工
# 3   2024-03-18  sh.600036      招商银行
# 4   2024-03-18  sh.600048      保利发展
# 5   2024-03-18  sh.600050      中国联通
# 6   2024-03-18  sh.600089      特变电工
# 7   2024-03-18  sh.600104      上汽集团
# 8   2024-03-18  sh.600111      北方稀土
# 9   2024-03-18  sh.600150      中国船舶
# 10  2024-03-18  sh.600276      恒瑞医药
# 11  2024-03-18  sh.600309      万华化学
# 12  2024-03-18  sh.600406      国电南瑞
# 13  2024-03-18  sh.600436       片仔癀
# 14  2024-03-18  sh.600438      通威股份
# 15  2024-03-18  sh.600519      贵州茅台
# 16  2024-03-18  sh.600690      海尔智家
# 17  2024-03-18  sh.600809      山西汾酒
# 18  2024-03-18  sh.600887      伊利股份
# 19  2024-03-18  sh.600893      航发动力
# 20  2024-03-18  sh.600900      长江电力
# 21  2024-03-18  sh.600905      三峡能源
# 22  2024-03-18  sh.601012      隆基绿能
# 23  2024-03-18  sh.601088      中国神华
# 24  2024-03-18  sh.601166      兴业银行
# ...

# %%
# import pandas as pd
# df = pd.DataFrame()
# for c in sz50_stocks.code:
#     rs = bs.query_history_k_data_plus(c, "date,code,close", start_date='2017-07-01', end_date='2022-11-18', frequency="d", adjustflag="3")
#     print(rs.get_data())
#     df = df.append(rs.get_data())

# def get_data(c):
#     rs = bs.query_history_k_data_plus(c, "date,code,close", start_date='2017-07-01', end_date='2022-11-18', frequency="d", adjustflag="3")
#     return rs.get_data()
# dfs = [get_data(c) for c in sz50_stocks.code]
# reduce(lambda a,b:a.join(b),dfs)

# %%
c = sz50_stocks.code.sample(1).iloc[0]

c
# Out:
# 'sh.603501'

# %%
import baostock as bs
import pandas as pd

#### 登陆系统 ####
lg = bs.login()
# 显示登陆返回信息
print('login respond error_code:'+lg.error_code)
print('login respond  error_msg:'+lg.error_msg)

#### 获取沪深A股历史K线数据 ####
# 详细指标参数，参见“历史行情指标参数”章节；“分钟线”参数与“日线”参数不同。“分钟线”不包含指数。
# 分钟线指标：date,time,code,open,high,low,close,volume,amount,adjustflag
# 周月线指标：date,code,open,high,low,close,volume,amount,adjustflag,turn,pctChg
rs = bs.query_history_k_data_plus(c,
    "date,code,open,high,low,close,preclose,volume,amount,adjustflag,turn,tradestatus,pctChg,isST",
    start_date='2023-01-01', end_date='2023-12-31',
    frequency="d", adjustflag="3")
print('query_history_k_data_plus respond error_code:'+rs.error_code)
print('query_history_k_data_plus respond  error_msg:'+rs.error_msg)

# rs.get_data()

#### 打印结果集 ####
data_list = []
while (rs.error_code == '0') & rs.next():
    # 获取一条记录，将记录合并在一起
    data_list.append(rs.get_row_data())
df = pd.DataFrame(data_list, columns=rs.fields)

# #### 结果集输出到csv文件 ####   
# result.to_csv("D:\\history_A_stock_k_data.csv", index=False)
# print(result)

#### 登出系统 ####
bs.logout()

df
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond  error_msg:success
# logout success!
#            date       code      open      high       low     close  preclose  \
# 0    2023-01-03  sh.603501   77.0000   77.5100   75.2800   77.4900   77.0900
# 1    2023-01-04  sh.603501   77.0000   78.5000   77.0000   77.8900   77.4900
# 2    2023-01-05  sh.603501   78.2300   80.3000   77.8000   79.5000   77.8900
# 3    2023-01-06  sh.603501   79.8000   83.3900   79.1300   81.5700   79.5000
# 4    2023-01-09  sh.603501   81.8800   84.4000   81.8100   83.0200   81.5700
# ..          ...        ...       ...       ...       ...       ...       ...
# 237  2023-12-25  sh.603501  108.0000  109.5800  107.3800  109.3600  108.6900
# 238  2023-12-26  sh.603501  109.5500  109.5500  105.7300  106.4700  109.3600
# 239  2023-12-27  sh.603501  105.6000  107.6400  105.3300  107.0500  106.4700
# ...

# %%
df[['open',	'high',	'low',	'close', 'volume','amount','pctChg']] = df[['open',	'high',	'low',	'close','volume','amount','pctChg']].astype(float)

# %%
import datetime
df.date.apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d').timestamp())
# Out:
# 0      1.672675e+09
# 1      1.672762e+09
# 2      1.672848e+09
# 3      1.672934e+09
# 4      1.673194e+09
#            ...
# 237    1.703434e+09
# 238    1.703520e+09
# 239    1.703606e+09
# 240    1.703693e+09
# 241    1.703779e+09
# Name: date, Length: 242, dtype: float64

# %%
from stockstats import StockDataFrame
import stockstats
sdf = StockDataFrame(df)
sdf = sdf[['close','pctChg','kdjk','kdjd','kdjj','rsi_6',"rsi_12",'rsi_24','boll_ub','boll_lb']]
# sdf['rsi_diff'] = sdf['rsi_6'] - sdf['rsi_12']
# sdf['kdj_diff'] = sdf['kdjj'] - sdf['kdjd']
# sdf['kdj_diff'] = (sdf['kdj_diff'] - sdf['kdj_diff'].mean())/sdf['kdj_diff'].std()
# sdf['rsi_diff'] = (sdf['rsi_diff'] - sdf['rsi_diff'].mean())/sdf['rsi_diff'].std()
# sdf[['close']].plot(subplots=True,figsize=(20,3), grid=True)

# %%
import cufflinks
cufflinks.getThemes()
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %%
cufflinks.colors.scales()
# Out:
# <div style="display:inline-block;padding:10px;"><div>accent</div><div style="background-color:rgb(127,201,127);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(190,174,212);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(253,192,134);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(255,255,153);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(56,108,176);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(240,2,127);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(191,91,23);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(102,102,102);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div></div><div
# ...

# %%
import cufflinks
sdf[['close','kdjk','kdjd','kdjj','boll_ub','boll_lb','pctchg']].iplot(kind="bar", subplots=True, shape=(3,4), theme = "white", colorscale="ggplot",labels = True)
# Out:
# <div>                            <div id="90cee7da-0faa-491c-b044-6efc8ee79f1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sdf
# Out:
#       close  pctchg       kdjk       kdjd       kdjj       rsi_6      rsi_12  \
# 0     77.49  0.5189  66.367713  55.455904  88.191330         NaN         NaN
# 1     77.89  0.5162  71.263776  60.725195  92.340937  100.000000  100.000000
# 2     79.50  2.0670  75.530432  65.660274  95.270748  100.000000  100.000000
# 3     81.57  2.6038  76.206478  69.175675  90.268083  100.000000  100.000000
# 4     83.02  1.7776  79.093792  72.481714  92.317948  100.000000  100.000000
# ..      ...     ...        ...        ...        ...         ...         ...
# 237  109.36  0.6164  70.241679  68.722403  73.280229   65.458061   58.228011
# 238  106.47 -2.6426  52.458854  63.301220  30.774121   38.326233   47.030515
# 239  107.05  0.5448  45.550675  57.384372  21.883281   43.923877   49.170561
# 240  108.85  1.6815  55.492027  56.753590  52.968902   58.089933   55.286572
# 241  106.71 -1.9660  46.844792  53.450658  33.633061   42.700400   47.823403
#
#          rsi_24     boll_ub     boll_lb
# ...

# %%
sdf[['close','boll_ub','boll_lb']].plot()
# Out:
# <Axes: >

# %%
sdf.pctchg.plot(kind="hist",bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
pd.DataFrame({
              c:sdf.close/sdf.close[0],
              # "ETF3x": (3*sdf.pctchg/100 +1).cumprod(),
              "pctchg_20_median": (sdf.pctchg/100).rolling(20).median(),
              "pctchg_20_mean": (sdf.pctchg/100).rolling(20).mean()
            }
            ).plot(colormap="tab10", subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# # About daily return

# %%
sdf.pctchg.rolling(40).median().plot()
sdf.pctchg.rolling(40).mean().plot()
# Out:
# <Axes: >

# %%
sdf.pctchg.rolling(20).std().plot()
# Out:
# <Axes: >

# %%
# 策略1 收益率mean>median
s1 = (sdf.pctchg[sdf.pctchg.rolling(20).mean()<sdf.pctchg.rolling(20).median()]/100 + 1).cumprod()
# 策略2 mean>0
s2 = (sdf.pctchg[sdf.pctchg.rolling(20).mean()>0.1]/100 + 1).cumprod()
# 策略3 median>0
s3 = (sdf.pctchg[sdf.pctchg.rolling(20).median()>0.1]/100 + 1).cumprod()
pd.DataFrame({"mean>median":s1,"mean>0.1":s2,"median>0.1":s3}).plot(colormap="viridis")
# Out:
# <Axes: >

# %%
s2.count()
# Out:
# 126

# %% [markdown]
# # Insight into bolling band

# %%
sdf[['close','boll_ub','boll_lb']].plot()
# Out:
# <Axes: >

# %%
# import seaborn as sns
# sns.set_theme(context="paper", style="white")
(sdf.boll_ub/sdf.close).plot()
(sdf.boll_lb/sdf.close).plot()
# Out:
# <Axes: >

# %%
sdf
# Out:
#       close  pctchg       kdjk       kdjd       kdjj       rsi_6      rsi_12  \
# 0     77.49  0.5189  66.367713  55.455904  88.191330         NaN         NaN
# 1     77.89  0.5162  71.263776  60.725195  92.340937  100.000000  100.000000
# 2     79.50  2.0670  75.530432  65.660274  95.270748  100.000000  100.000000
# 3     81.57  2.6038  76.206478  69.175675  90.268083  100.000000  100.000000
# 4     83.02  1.7776  79.093792  72.481714  92.317948  100.000000  100.000000
# ..      ...     ...        ...        ...        ...         ...         ...
# 237  109.36  0.6164  70.241679  68.722403  73.280229   65.458061   58.228011
# 238  106.47 -2.6426  52.458854  63.301220  30.774121   38.326233   47.030515
# 239  107.05  0.5448  45.550675  57.384372  21.883281   43.923877   49.170561
# 240  108.85  1.6815  55.492027  56.753590  52.968902   58.089933   55.286572
# 241  106.71 -1.9660  46.844792  53.450658  33.633061   42.700400   47.823403
#
#          rsi_24     boll_ub     boll_lb
# ...

# %% [markdown]
# # Kneading KDJ

# %%
import kdj
kr = kdj.kdj_area(sdf, 9)
kr.iplot(kind='bar',opacity=0.5,theme = "white",colorscale="Set1")
# Out:
# <div>                            <div id="b3adcf2c-ed69-4463-b984-45eedf97f0ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d = sdf
knot = 6
kr = d['kdjj'] - d['kdjd']
kr = (kr-kr.mean())/kr.std()    # z-score normalization
# kr.plot(figsize=(20,2),  grid=True, alpha=0.7, color='green', kind='bar')
kr.iplot(shape=(20,2), kind='bar',theme = "white", colorscale="ggplot")
# Out:
# <div>                            <div id="0b6a83cc-63ad-4d96-8614-a589b9383bd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
####### 
kr_ = kr.fillna(0).shift(1).fillna(0)
flex = kr[kr*kr_ <0].index      # 拐点
flex
# Out:
# Int64Index([  7,   9,  15,  24,  27,  36,  40,  45,  55,  59,  66,  79,  94,
#              97,  99, 106, 113, 119, 127, 137, 144, 156, 171, 173, 175, 177,
#             179, 183, 189, 196, 199, 202, 205, 217, 224, 227, 232, 233, 238],
#            dtype='int64')

# %%
knot = flex[-9]
knot
# Out:
# 199

# %%
kr_cumsum = kr[knot:].cumsum()
import matplotlib.pyplot as plt
fig, axes = plt.subplots(3,1)
sdf[['kdjd','kdjj']][knot:].plot(ax=axes[0],figsize=(20,5),  grid=True, alpha=0.7, kind='line')
sdf.close[knot:].iplot(ax=axes[1], kind='line', color='green')
# kr_cumsum.plot(ax=axes[2],figsize=(20,5),  grid=True, alpha=0.7, color='blue',kind='bar')
kr_cumsum.iplot(ax=axes[1],theme = "white",colorscale="Set2",kind='bar',fill="Set2")
# Out:
# <div>                            <div id="1cd76ef8-93e0-47d2-aa4d-3093676bfb63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sdf.close.iplot(subplots=True, color='green')
# Out:
# <div>                            <div id="60841852-2d63-40e7-9501-7713720e150a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
kr1 = kr.shift(1)
flex = kr[kr*kr1 <0].index # 拐点
flex
# Out:
# Int64Index([  7,   9,  15,  24,  27,  36,  40,  45,  55,  59,  66,  79,  94,
#              97,  99, 106, 113, 119, 127, 137, 144, 156, 171, 173, 175, 177,
#             179, 183, 189, 196, 199, 202, 205, 217, 224, 227, 232, 233, 238],
#            dtype='int64')

# %%
flex = pd.DataFrame(flex,columns=['a'])
flex
# Out:
#       a
# 0     7
# 1     9
# 2    15
# 3    24
# 4    27
# 5    36
# 6    40
# 7    45
# 8    55
# 9    59
# 10   66
# 11   79
# 12   94
# 13   97
# 14   99
# 15  106
# 16  113
# 17  119
# 18  127
# 19  137
# 20  144
# 21  156
# 22  171
# 23  173
# 24  175
# 25  177
# 26  179
# 27  183
# 28  189
# 29  196
# 30  199
# 31  202
# 32  205
# 33  217
# 34  224
# 35  227
# 36  232
# 37  233
# 38  238

# %%
flex.loc[len(flex)] = [kr.index[-1]]
flex
# Out:
#       a
# 0     7
# 1     9
# 2    15
# 3    24
# 4    27
# 5    36
# 6    40
# 7    45
# 8    55
# 9    59
# 10   66
# 11   79
# 12   94
# 13   97
# 14   99
# 15  106
# 16  113
# 17  119
# 18  127
# 19  137
# 20  144
# 21  156
# 22  171
# 23  173
# 24  175
# 25  177
# 26  179
# 27  183
# 28  189
# 29  196
# 30  199
# 31  202
# 32  205
# 33  217
# 34  224
# 35  227
# 36  232
# 37  233
# 38  238
# 39  241

# %%
flex = pd.DataFrame(flex,columns=['a'])
flex['b'] = flex.a.shift(-1).astype("Int64")
flex.dropna(inplace=True) #     去掉最后带na的那行。(拐点,下一个拐点)终于有了
flex
# Out:
#       a    b
# 0     7    9
# 1     9   15
# 2    15   24
# 3    24   27
# 4    27   36
# 5    36   40
# 6    40   45
# 7    45   55
# 8    55   59
# 9    59   66
# 10   66   79
# 11   79   94
# 12   94   97
# 13   97   99
# 14   99  106
# 15  106  113
# 16  113  119
# 17  119  127
# 18  127  137
# 19  137  144
# 20  144  156
# 21  156  171
# 22  171  173
# 23  173  175
# 24  175  177
# 25  177  179
# 26  179  183
# 27  183  189
# 28  189  196
# 29  196  199
# 30  199  202
# 31  202  205
# 32  205  217
# 33  217  224
# 34  224  227
# 35  227  232
# 36  232  233
# 37  233  238
# 38  238  241

# %%
kr.index[-1]
# Out:
# 241

# %%
kr = pd.DataFrame(kr).fillna(0)
kr.head(20)
# Out:
#            0
# 0   1.181138
# 1   1.140632
# 2   1.068090
# 3   0.759942
# 4   0.714498
# 5   0.569704
# 6   0.051516
# 7  -0.135838
# 8  -0.082791
# 9   0.341073
# 10  0.427893
# 11  0.420674
# 12  0.579221
# 13  0.462140
# 14  0.015727
# 15 -0.444513
# 16 -0.519910
# 17 -0.462011
# 18 -1.308254
# 19 -2.165244

# %%
def seg_cumsum(x):
    kr.iloc[x.a:x.b] = kr.iloc[x.a:x.b].cumsum()
    return kr.iloc[x.a:x.b]
       
flex.apply(seg_cumsum, axis=1)
# Out:
# 0                             0
# 7 -0.135838
# 8 -0.218629
# 1                0
# 9   0.341073
# 10  0.768966
# 11  1.1...
# 2                 0
# 15  -0.444513
# 16  -0.964424
# 17  ...
# 3                0
# 24  0.527550
# 25  1.081928
# 26  2.0...
# 4                0
# 27 -0.165713
# 28 -1.324586
# 29 -2.1...
# 5                0
# 36  0.119694
# 37  0.491875
# 38  1.1...
# 6                0
# 40 -0.328850
# 41 -0.593085
# 42 -1.0...
# 7                 0
# 45   0.556365
# 46   1.364546
# 47  ...
# 8                0
# 55 -0.570705
# 56 -1.050925
# 57 -1.3...
# 9                0
# 59  0.437906
# 60  0.859069
# 61  1.1...
# 10                0
# 66  -0.494315
# 67  -0.968805
# 68  ...
# 11                0
# 79   0.058449
# 80   0.291122
# 81  ...
# 12               0
# 94 -0.035103
# 95 -0.148002
# 96 -0.5...
# 13                          0
# 97  0.262649
# 98  0.490152
# 14                0
# 99  -0.112473
# 100 -0.669913
# 101 ...
# 15                0
# 106  0.869395
# ...

# %%
kr.head(30)
# Out:
#             0
# 0    1.181138
# 1    1.140632
# 2    1.068090
# 3    0.759942
# 4    0.714498
# 5    0.569704
# 6    0.051516
# 7   -0.135838
# 8   -0.218629
# 9    0.341073
# 10   0.768966
# 11   1.189641
# 12   1.768862
# 13   2.231002
# 14   2.246728
# 15  -0.444513
# 16  -0.964424
# 17  -1.426435
# 18  -2.734689
# 19  -4.899933
# 20  -7.120181
# 21  -9.336920
# 22 -10.277407
# 23 -10.382636
# 24   0.527550
# 25   1.081928
# 26   2.087422
# 27  -0.165713
# 28  -1.324586
# 29  -2.137623

# %%
# kr.plot(subplots=True,kind='bar',figsize=(20,2),  grid=True, alpha=0.7, color='green')
kr.iplot(subplots=True,kind='bar',colorscale="set1")
# Out:
# <div>                            <div id="f1561794-e3f0-49e8-a3f7-0a4fcd356eeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sdf.close.plot(kind='line',figsize=(10,2),  grid=True, alpha=0.7, color='green')
# Out:
# <Axes: >

# %%
# sdf[['kdjj','kdjd']].plot(subplots=False,figsize=(20,2), grid=True)
sdf[['boll_ub','boll_lb','close']].iplot(kind='line', subplots=False)
# Out:
# <div>                            <div id="45fdfa7f-6475-42e8-9f98-dfa62baabedc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sdf['gap'] = (sdf.boll_ub - sdf.boll_lb) #/sdf.boll
sdf[['gap','close']].iplot(subplots=True, shape=(2,1),kind='bar', opacity=0.5)
# Out:
# <div>                            <div id="a3fa1541-f6db-4809-b491-e11ad656080c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sdf[['rsi_6','rsi_12']].tail(50).iplot(subplots=False)
# Out:
# <div>                            <div id="021e821c-131f-4014-adee-1ff9f2840a96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d1 = pd.read_csv("Test/Macd/20230307.1510sh.601211.csv", index_col=0)
d1[['close', 'action', 'reward']].tail(50).iplot(subplots=True,shape=(1,3))
# Out:
# <div>                            <div id="3d1ce8c4-485c-4a6c-8f44-64c6f5b55156" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d1.reward.mean()
# Out:
# -0.024913954009594376

# %%
import pandas_ta as ta
rsi = df.ta.rsi(14)
kdj = df.ta.kdj()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1079], line 1
# ----> 1 import pandas_ta as ta
#       2 rsi = df.ta.rsi(14)
#       3 kdj = df.ta.kdj()
#
# ModuleNotFoundError: No module named 'pandas_ta'

# %%
import numpy as np
def super_smoother(data:np.array, length) -> np.array:
    a1 = np.exp(-1.414 * 3.14159 / (0.5 * length))
    b1 = 2 * a1 * np.cos(1.414 * 180 / (0.5 * length))
    c2 = b1
    c3 = -a1 * a1
    c1 = 1 - c2 - c3

    # filt = [0] * len(data)
    filt = np.zeros_like(data)
    filt[0] = data[0]
    filt[1] = c1 * (data[0] + data[1]) / 2 + (c2+c3) * filt[0]
    for i in range(2, len(data)):
        filt[i] = c1 * (data[i] + data[i - 1]) / 2 + c2 * filt[i - 1] + c3 * filt[i - 2]
        
    return filt

# data = [100, 110, 120, 115, 130, 142, 122, 108, 130]
data = df.close
smoothed = super_smoother(data, length=20)

# %%
import seaborn as sns
sns.lineplot((data,smoothed))
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np

def reflex_indicator(data:np.array, length):
    # Gently smooth the data in a SuperSmoother
    filt = super_smoother(data, length)


    # Length is assumed cycle period 
    # slope = (filt[-length - 1] - filt[-1]) / length
    # 计算斜率，上面代码有问题 
    slope = (filt - pd.DataFrame(filt).shift(length).values.squeeze(1))/length
    # print(slope)

    # Sum the differences
    from functools import reduce
    sum = np.zeros_like(filt)
    diff = lambda c: filt[i-length] + c * slope[i] - filt[i-length+c]
    for i in range(length, len(filt)):
        diffs = [diff(c) for c in range(0,length)]
        sum[i] = reduce(lambda a,b: a + b, diffs)
    sum /= length
    # print(sum)
        
    # summation = 0
    # for count in range(1, length + 1):
    #     summation += (filt[-1] + count * slope) - filt[-count]
    # summation /= length

    # Normalize in terms of Standard Deviations
    # ms = 0.04 * summation * summation + 0.96 * ms[-1]
    ms = np.zeros_like(filt)
    ms[0] = sum[0]**2
    for i in range(1,len(filt)):
        ms[i] = 0.04*sum[i]**2 + 0.96*ms[i-1]

    # if ms != 0:
    reflex = sum / np.sqrt(ms)
    return reflex

# 示例用法
length = 20
# data = [100, 110, 120, 115, 130, 142, 122, 108, 130]
data = df.close
reflex = reflex_indicator(data, length)
reflex
# Out:
# array([            nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#        -5.00000000e+00, -4.28909215e+00, -3.67335915e+00, -3.06378923e+00,
#        -2.52222287e+00, -2.04289762e+00, -1.72263259e+00, -1.54432007e+00,
#        -1.42671583e+00, -1.13748364e+00, -5.86939346e-01, -3.34347133e-02,
#         3.50103017e-01,  5.85418154e-01,  8.29000873e-01,  9.74810520e-01,
#         9.86667282e-01,  9.64237454e-01,  7.70290956e-01,  3.68654599e-01,
#        -2.38723016e-01, -9.59261744e-01, -1.52459099e+00, -1.77384625e+00,
#        -1.67838818e+00, -1.38199125e+00, -1.14266440e+00, -1.09894992e+00,
# ...

# %%
import seaborn as sns
sns.lineplot(reflex)
# Out:
# <Axes: >

# %%
sns.lineplot((data,smoothed))
# Out:
# <Axes: >

# %%
sdf
# Out:
#       close       kdjk       kdjd       kdjj      rsi_6     rsi_12     rsi_24  \
# 0    283.88  38.867925  46.289308  24.025157        NaN        NaN        NaN
# 1    281.40  31.385956  41.321524  11.514819   0.000000   0.000000   0.000000
# 2    289.90  49.388701  44.010583  60.144937  80.441640  78.898515  78.148943
# 3    288.00  56.134653  48.051940  72.300079  66.165023  66.168145  66.100148
# 4    291.48  64.938169  53.680683  87.453141  75.659653  74.416199  73.815748
# ..      ...        ...        ...        ...        ...        ...        ...
# 157  270.60   9.923692  16.400038  -3.029001  17.821733  28.571983  37.421386
# 158  275.23  15.234842  16.011639  13.681247  37.468129  38.023977  41.789675
# 159  276.65  21.556129  17.859803  28.948781  42.525125  40.651581  43.061657
# 160  278.57  29.210008  21.643204  44.343615  49.191933  44.144614  44.764580
# 161  276.34  33.834340  25.706916  50.089187  42.345938  41.081048  43.198737
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Test/Boll/20231017.1713sh.600010.csv",header=0, index_col=0)
df.tail(100).iplot(y=['close','action','reward'], subplots=True, theme="white", colorscale="set1",shape=(1,3), kind='line')
# Out:
# <div>                            <div id="9c98fe3f-b64e-479a-a84c-554b2317b887" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.tail(100).action.iplot(kind="line")
# Out:
# <div>                            <div id="e7411ec8-74e5-42fe-819d-e332db9380a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
from globals import summary, etf_action
import os
from pathlib import Path
from functools import reduce
import pandas as pd

data_folder = Path(f"Test/Kdj")
files = os.listdir(str(data_folder))  # 目录下所有文件,
files = [f for f in files if os.path.splitext(f)[1] == '.csv']  # 只选择 .csv 文件,
if summary in files: 
    files.remove(summary)
if etf_action in files: 
    files.remove(etf_action)  # 如果已经有了要去掉
print(f"Testing ETF strategy Kdj with {files}")
# 读取所有files，组成一个dataframe或者list of dataframe
df_list = [pd.read_csv(data_folder/f, index_col=0 ,header=0) for f in files]
df_list = reduce(lambda a,b: pd.concat([a,b]), df_list)
df_list = df_list.sort_values(by=['date', 'ticker']).reset_index(drop=True) # 按时间-股票对排序,并且去掉index
days = df_list.date.drop_duplicates() # 去掉重复的日期
days
# Out:
# Testing ETF strategy Kdj with ['20230824.1706sh.600196.csv', '20230824.1706sh.601288.csv', '20230824.1706sh.600036.csv', '20230824.1706sh.601066.csv', '20230824.1706sh.601398.csv', '20230824.1706sh.601012.csv', '20230824.1706sh.600438.csv', '20230824.1706sh.600809.csv', '20230824.1706sh.600837.csv', '20230824.1706sh.601668.csv']
# 0        2015-11-05
# 5        2015-11-06
# 10       2015-11-09
# 15       2015-11-10
# 20       2015-11-11
#             ...
# 18188    2023-08-17
# 18198    2023-08-18
# 18208    2023-08-21
# 18218    2023-08-22
# 18228    2023-08-23
# Name: date, Length: 1900, dtype: object

# %%
for day in days:
    print(day)
    df = df_list[df_list.date == day]
    # print(df)
    df = df.sort_values(by=['date', 'ticker']).reset_index(drop=True) # 按时间-股票对排序,并且去掉index
# Out:
# 2015-11-05
# 2015-11-06
# 2015-11-09
# 2015-11-10
# 2015-11-11
# 2015-11-12
# 2015-11-13
# 2015-11-16
# 2015-11-17
# 2015-11-18
# 2015-11-19
# 2015-11-20
# 2015-11-23
# 2015-11-24
# 2015-11-25
# 2015-11-26
# 2015-11-27
# 2015-11-30
# 2015-12-01
# 2015-12-02
# 2015-12-03
# 2015-12-04
# 2015-12-07
# 2015-12-08
# 2015-12-09
# 2015-12-10
# 2015-12-11
# 2015-12-14
# 2015-12-15
# 2015-12-16
# 2015-12-17
# 2015-12-18
# 2015-12-21
# 2015-12-22
# 2015-12-23
# 2015-12-24
# 2015-12-25
# 2015-12-28
# 2015-12-29
# 2015-12-30
# 2015-12-31
# 2016-01-04
# 2016-01-05
# 2016-01-06
# 2016-01-07
# 2016-01-08
# 2016-01-11
# 2016-01-12
# 2016-01-13
# 2016-01-14
# 2016-01-15
# 2016-01-18
# 2016-01-19
# 2016-01-20
# 2016-01-21
# 2016-01-22
# 2016-01-25
# 2016-01-26
# 2016-01-27
# 2016-01-28
# 2016-01-29
# 2016-02-01
# 2016-02-02
# 2016-02-03
# 2016-02-04
# 2016-02-05
# 2016-02-15
# 2016-02-16
# 2016-02-17
# 2016-02-18
# 2016-02-19
# 2016-02-22
# 2016-02-23
# 2016-02-24
# 2016-02-25
# 2016-02-26
# ...

# %%
df_list.columns
# Out:
# Index(['ticker', 'date', 'close', 'action', 'reward', 'change_wo_short',
#        'change_w_short'],
#       dtype='object')
